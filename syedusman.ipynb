# %%
"""1. Create a python program that asks the user how far they want to travel, if they want to travel less than three miles tell them to ride Bicycle. if they want to travel more than three miles, but less than three hundred miles, tell them to ride Motor-Cycle, if they want to travel three hundred miles or more tell them to drive Super-Car """

miles=int(input("how many miles do you want to travel:"))

if miles>=0 and miles<3:

  print("take a bicycle")

elif miles>=3 and miles<300:

  print("take a motor cycle")

elif miles>=300:

   print("take a super car")

else:

   print("enter valid distance")
# Out:
# how many miles do you want to travel: 300
# take a super car

# %%
"""2. An App for Mobile hosting provider charges-
918?"""

charge=0.51

day=24*charge

week=24*7*charge

month= 30 *24 *charge

print("cost per day =$", day)

print("cost per month =$", week)

print("cost per year =$", month)

cost=918

ndays=int (cost/day)

print("I can operate one server for days =",ndays)
# Out:
# cost per day =$ 12.24
# cost per month =$ 85.68
# cost per year =$ 367.2
# I can operate one server for days = 75

# %%
"""3. You're building a small program for a school. The user must enter the student's name and marks in three subjects. The program should calculate the total, average, and display a grade. If marks are not between 0 and 100, show an error message.

Concepts: Input/Output, data validation, arithmetic, if-elif-else."""

stu_name = input("Enter student's name: ")
while True:
    try:
        sub1_marks = int(input("Enter marks for Subject 1 (0-100): "))
        if 0 <= sub1_marks <= 100:
            break
        else:
            print("Error: Marks must be between 0 and 100. Please try again.")
    except ValueError:
        print("Error: Invalid input. Please enter a whole number.")
while True:
    try:
        sub2_marks = int(input("Enter marks for Subject 2 (0-100): "))
        if 0 <= sub2_marks <= 100:
            break
        else:
            print("Error: Marks must be between 0 and 100. Please try again.")
    except ValueError:
        print("Error: Invalid input. Please enter a whole number.")
while True:
    try:
        sub3_marks = int(input("Enter marks for Subject 3 (0-100): "))
        if 0 <= sub3_marks <= 100:
            break
        else:
            print("Error: Marks must be between 0 and 100. Please try again.")
    except ValueError:
        print("Error: Invalid input. Please enter a whole number.")
total_marks = sub1_marks + sub2_marks + sub3_marks
avge_marks = total_marks / 3
if avge_marks >= 90:
    grade = 'A'
elif avge_marks >= 80:
    grade = 'B'
elif avge_marks >= 70:
    grade = 'C'
elif avge_marks >= 60:
    grade = 'D'
else:
    grade = 'F'
print(f"Student Name: {stu_name}")
print(f"Total Marks: {total_marks}")
print(f"Average Marks: {avge_marks:.2f}")
print(f"Grade: {grade}")
# Out:
# Enter student's name:  Syed Usman
# Enter marks for Subject 1 (0-100):  90
# Enter marks for Subject 2 (0-100):  85
# Enter marks for Subject 3 (0-100):  80
# Student Name: Syed Usman
# Total Marks: 255
# Average Marks: 85.00
# Grade: B

# %%
""" 4.	A traffic system records the average speed of vehicles every hour for 12 hours.
Write a program that: Reads 12 speed values (floats). Calculates the average speed. Displays whether traffic flow was “Slow” (avg < 40), “Normal” (40–80), or “Fast” (avg > 80)."""
spds = []
for i in range(1, 13):
            spd_input = input(f"Enter the average speed for hour {i}: ")
            spd = float(spd_input)
            spds.append(spd)
if spds:
    total_speed = sum(spds)
    average_speed = total_speed / len(spds)
else:
    average_speed = 0
print(f"\nThe average traffic speed over 12 hours is: {average_speed:.2f} km/h")
if average_speed < 40:
    print("Traffic flow status: Slow")
elif 40 <= average_speed <= 80:
    print("Traffic flow status: Normal")
else:
    print("Traffic flow status: Fast")
# Out:
# Enter the average speed for hour 1:  50
# Enter the average speed for hour 2:  70
# Enter the average speed for hour 3:  90
# Enter the average speed for hour 4:  95
# Enter the average speed for hour 5:  100
# Enter the average speed for hour 6:  100
# Enter the average speed for hour 7:  100
# Enter the average speed for hour 8:  100
# Enter the average speed for hour 9:  100
# Enter the average speed for hour 10:  100
# Enter the average speed for hour 11:  100
# Enter the average speed for hour 12:  100
# The average traffic speed over 12 hours is: 92.08 km/h
# Traffic flow status: Fast

# %%
"""5. Design a module math_utils.py with functions:
factorial(n)
is_prime(n)
gcd(a,b)
Include exception handling for invalid or negative inputs. Import and test these functions from another script."""

def factorial(n):
    if not isinstance(n, int):
        raise ValueError("Input must be an integer.")
    if n < 0:
        raise ValueError("Factorial is not defined for negative numbers.")
    if n == 0:
        return 1
    result = 1
    for i in range(1, n + 1):
        result *= i
    return result

def is_prime(n):
    if not isinstance(n, int):
        raise ValueError("Input must be an integer.")
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

def gcd(a, b):
    if not isinstance(a, int) or not isinstance(b, int):
        raise ValueError("Inputs must be integers.")
    while b:
        a, b = b, a % b
    return a

print("Testing factorial function:")
try:
    print(f"Factorial of 5: {factorial(5)}")
    print(f"Factorial of 0: {factorial(0)}")
except ValueError as e:
    print(f"Error: {e}")

print("\nTesting is_prime function:")
try:
    print(f"Is 7 prime? {is_prime(7)}")
    print(f"Is 10 prime? {is_prime(10)}")
    print(f"Is 1 prime? {is_prime(1)}")
except ValueError as e:
    print(f"Error: {e}")

print("\nTesting gcd function:")
try:
    print(f"GCD of 48 and 18: {gcd(48, 18)}")
    print(f"GCD of 17 and 5: {gcd(17, 5)}")
except ValueError as e:
    print(f"Error: {e}")
# Out:
# Testing factorial function:
# Factorial of 5: 120
# Factorial of 0: 1
#
# Testing is_prime function:
# Is 7 prime? True
# Is 10 prime? False
# Is 1 prime? False
#
# Testing gcd function:
# GCD of 48 and 18: 6
# GCD of 17 and 5: 1

# %%
"""6. A company needs a program that reads employee names and their basic salary.
The program should: Calculate total salary including HRA (20%) and DA (10%).
Stop taking input when the user types "stop". Display each employee’s total salary at the end."""
def calculate_employee_salaries():
    employee_salaries = {}

    print("Enter employee names and their basic salary.")
    print("Type 'stop' for the name when you are finished.")

    while True:
        name = input("Enter employee name: ")
        if name.lower() == 'stop':
            break
        try:
            basic_salary_input = input(f"Enter basic salary for {name}: ")
            basic_salary = float(basic_salary_input)
        except ValueError:
            print("Invalid input for salary. Please enter a number.")
            continue
        hra = 0.20 * basic_salary
        da = 0.10 * basic_salary
        total_salary = basic_salary + hra + da
        employee_salaries[name] = total_salary
    print("\nEmployee Total Salaries")
    if not employee_salaries:
        print("No employee data was entered.")
    else:
        for name, salary in employee_salaries.items():
            print(f"the total salary of {name} is Rs{salary:,.2f}")
calculate_employee_salaries()
# Out:
# Enter employee names and their basic salary.
# Type 'stop' for the name when you are finished.
# Enter employee name:  abhi
# Enter basic salary for abhi:  100000
# Enter employee name:  ravi
# Enter basic salary for ravi:  200000
# Enter employee name:  usman
# Enter basic salary for usman:  4000000
# Enter employee name:  hannan
# Enter basic salary for hannan:  20020200202
# Enter employee name:  yooo
# Enter basic salary for yooo:  500000000000
# Enter employee name:  stop
# Employee Total Salaries
# the total salary of abhi is Rs130,000.00
# the total salary of ravi is Rs260,000.00
# the total salary of usman is Rs5,200,000.00
# the total salary of hannan is Rs26,026,260,262.60
# the total salary of yooo is Rs650,000,000,000.00

# %%
""" 7.Given list of items purchased in a file display the following: No of items purchased, No of free items, Amount to pay, Discount given, Final amount paid"""
def process_custom_purchase_file(filename):
    total_items = 0
    free_items = 0
    amount_to_pay = 0
    discount_given = 0
    try:
        with open(filename, 'r') as file:
            for line in file:
                line = line.strip()
                if not line:
                    continue
                parts = line.split()
                if not parts:
                    continue
                item_name = parts[0]
                value_str = parts[-1]
                if item_name.lower() == 'discount' and value_str.isdigit():
                    discount_given = int(value_str)
                    continue
                if value_str.lower() == 'free':
                    free_items += 1
                    total_items += 1
                    continue
                try:
                    price = float(value_str)
                    quantity = 1
                    total_items += quantity
                    amount_to_pay += price * quantity
                except ValueError:
                    print(f"Warning: Skipping unrecognised line format in {filename}: {line}")
                    continue
        final_amount_paid = amount_to_pay - discount_given
        print(f"Sample output for {filename} file:")
        print(f"No of items purchased: {total_items}")
        print(f"No of free items: {free_items}")
        print(f"Amount to pay: {amount_to_pay:.2f}")
        print(f"Discount given: {discount_given:.2f}")
        print(f"Final amount paid: {final_amount_paid:.2f}")
        print(f"\n")
    except FileNotFoundError:
        print(f"Error: The file {filename} was not found.")
    except IOError as e:
        print(f"An I/O error occurred while reading {filename}: {e}")
def create_custom_test_files():
    with open("purchase1.txt", "w") as f1:
        f1.write("Chocolate 50\n")
        f1.write("Biscuit 35\n")
        f1.write("Icecream 50\n")
        f1.write("\n")
        f1.write("Discount 5\n")
    with open("purchase2.txt", "w") as f2:
        f2.write("Chocolate 50\n")
        f2.write("Biscuit 35\n")
        f2.write("Icecream 50\n")
        f2.write("Rice 100\n")
        f2.write("Chicken 250\n")
        f2.write("\n")
        f2.write("Perfume Free\n")
        f2.write("Soup Free\n")
        f2.write("\n")
        f2.write("Discount 80\n")
create_custom_test_files()
process_custom_purchase_file("purchase1.txt")
process_custom_purchase_file("purchase2.txt")
# Out:
# Sample output for purchase1.txt file:
# No of items purchased: 3
# No of free items: 0
# Amount to pay: 135.00
# Discount given: 5.00
# Final amount paid: 130.00
#
#
# Sample output for purchase2.txt file:
# No of items purchased: 7
# No of free items: 2
# Amount to pay: 485.00
# Discount given: 80.00
# Final amount paid: 405.00

# %%
"""8. Output dictionary which contains only the odd numbers that are present in the input list as keys and their cubes as values using List Comprehension"""
input_list=[1,2,3,4,5,6,7]
oddcubes_dict={num:num**3 for num in input_list if num %2 !=0}
print(oddcubes_dict)
# Out:
# {1: 1, 3: 27, 5: 125, 7: 343}
